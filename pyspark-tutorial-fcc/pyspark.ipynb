# %%
import pyspark

# %%
print("Hello World")
# Out:
# Hello World

# %%
import datetime

now = datetime.datetime.now()
print("Current date and time: ")
print(now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time:
# 2025-11-22 12:51:50

# %%
# cell 1
import os, sys, time
print("Python executable:", sys.executable)
print("JAVA_HOME (env):", os.environ.get("JAVA_HOME"))
print("HADOOP_HOME (env):", os.environ.get("HADOOP_HOME"))
try:
    import pyspark
    print("pyspark version:", pyspark.__version__)
    print("pyspark installed at:", pyspark.__file__)
except Exception as e:
    print("pyspark import error:", e)
# Out:
# Python executable: /usr/bin/python3
# JAVA_HOME (env): None
# HADOOP_HOME (env): None
# pyspark version: 3.5.1
# pyspark installed at: /usr/local/lib/python3.12/dist-packages/pyspark/__init__.py

# %%
from pyspark.sql import SparkSession

#need to install a jdk

# %%
# from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("PysparkLearnings").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://029b5a928bcb:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PysparkLearnings</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.option('header','true').csv('superstore.csv')
df.show(5)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-47724558.py in <cell line: 0>()
# ----> 1 df = spark.read.option('header','true').csv('superstore.csv')
#       2 df.show(5)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     738         if type(path) == list:
#     739             assert self._spark._sc._jvm is not None
# ...
